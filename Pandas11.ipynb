# %%
import pandas as pd
df = pd.read_csv('KCLT.csv')

# %%
df[(df.actual_mean_temp < 20) | (df.actual_mean_temp > 86)][['date', 'actual_mean_temp']]
# Out:
# 191   2015-01-08
# 233   2015-02-19
# 234   2015-02-20
# 352   2015-06-18
# 357   2015-06-23
# 358   2015-06-24
# Name: date, dtype: datetime64[ns]

# %%
df['date']=pd.to_datetime(df.date)

# %%
df[(df.actual_mean_temp < 20) | (df.actual_mean_temp > 86)][['date', 'actual_mean_temp']]
# Out:
#           date  actual_mean_temp
# 191 2015-01-08                18
# 233 2015-02-19                19
# 234 2015-02-20                19
# 352 2015-06-18                87
# 357 2015-06-23                87
# 358 2015-06-24                88

# %%
df.head()
# Out:
#         date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0 2014-07-01                81               70               91
# 1 2014-07-02                85               74               95
# 2 2014-07-03                82               71               93
# 3 2014-07-04                75               64               86
# 4 2014-07-05                72               60               84
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                67                89               56              104
# 1                68                89               56              101
# 2                68                89               56               99
# 3                68                89               55               99
# 4                68                89               57              100
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1919                  2012                  0.00
# ...

# %%
import pandas as pd
df = pd.read_csv('kclt.csv')
df['date'] = pd.to_datetime(df.date)
df[(df.actual_mean_temp < 20) | (df.actual_mean_temp > 86)].date
df[(df.actual_mean_temp < 20) | (df.actual_mean_temp > 86)][['date', 'actual_mean_temp']]
df.date[0].year
df[df.date > '2015-06-01'].date.head(2)
# Out:
# 336   2015-06-02
# 337   2015-06-03
# Name: date, dtype: datetime64[ns]

# %%
df[(df.actual_mean_temp < 20) | (df.actual_mean_temp > 86)].date
# Out:
# 191   2015-01-08
# 233   2015-02-19
# 234   2015-02-20
# 352   2015-06-18
# 357   2015-06-23
# 358   2015-06-24
# Name: date, dtype: datetime64[ns]

# %%
df = pd.read_excel('ltus.xlsx')

# %%
df.head()
# Out:
#               Age Gender     Period  Unemployed
# 0  16 to 19 years    Men 2005-01-01       91000
# 1  20 to 24 years    Men 2005-01-01      175000
# 2  25 to 34 years    Men 2005-01-01      194000
# 3  35 to 44 years    Men 2005-01-01      201000
# 4  45 to 54 years    Men 2005-01-01      207000

# %%
df['Period'] = pd.to_datetime(df.Period)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1708 entries, 0 to 1707
# Data columns (total 4 columns):
# Age           1708 non-null object
# Gender        1708 non-null object
# Period        1708 non-null datetime64[ns]
# Unemployed    1708 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 53.5+ KB

# %%
df[(df.Period > '2006-12-31') & (df.Period < '2007-12-02')&(df.Gender == 'Women')]
# Out:
#                    Age Gender     Period  Unemployed
# 343     16 to 19 years  Women 2007-01-01       33000
# 344     20 to 24 years  Women 2007-01-01       43000
# 345     25 to 34 years  Women 2007-01-01      126000
# 346     35 to 44 years  Women 2007-01-01      114000
# 347     45 to 54 years  Women 2007-01-01      137000
# 348     55 to 64 years  Women 2007-01-01       72000
# 349  65 years and over  Women 2007-01-01       81000
# 357     16 to 19 years  Women 2007-02-01       37000
# 358     20 to 24 years  Women 2007-02-01       45000
# 359     25 to 34 years  Women 2007-02-01      127000
# 360     35 to 44 years  Women 2007-02-01      124000
# 361     45 to 54 years  Women 2007-02-01      125000
# 362     55 to 64 years  Women 2007-02-01       50000
# 363  65 years and over  Women 2007-02-01       55000
# 371     16 to 19 years  Women 2007-03-01       24000
# 372     20 to 24 years  Women 2007-03-01       35000
# 373     25 to 34 years  Women 2007-03-01      135000
# ...

# %%
df[(df.Period > '2006-12-31') & (df.Period < '2007-12-02')&(df.Gender == 'Women')].agg(['mean'])
# Out:
#       Unemployed
# mean     87000.0

# %%
df[(df.Period > '2006-12-31') & (df.Period < '2007-12-02')&(df.Gender == 'Men')].agg(['mean'])
# Out:
#          Unemployed
# mean  100845.238095

# %%
df['Period'] = df.Period.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-3ac89f39df23> in <module>()
# ----> 1 df['Period'] = df.Period.month
#
# C:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
df['Period'] = pd.DatetimeIndex(df['Period']).month

# %%
df.head()
# Out:
#               Age Gender  Period  Unemployed
# 0  16 to 19 years    Men       1       91000
# 1  20 to 24 years    Men       1      175000
# 2  25 to 34 years    Men       1      194000
# 3  35 to 44 years    Men       1      201000
# 4  45 to 54 years    Men       1      207000

# %%
df[df.Period== 1].head()
# Out:
#               Age Gender  Period  Unemployed
# 0  16 to 19 years    Men       1       91000
# 1  20 to 24 years    Men       1      175000
# 2  25 to 34 years    Men       1      194000
# 3  35 to 44 years    Men       1      201000
# 4  45 to 54 years    Men       1      207000

# %%
for n in range (13):
    print(df[df.Period== n].agg(['mean']))
# Out:
#       Age  Gender  Period  Unemployed
# mean  NaN     NaN     NaN         NaN
#       Period     Unemployed
# mean     1.0  252519.480519
#       Period     Unemployed
# mean     2.0  253350.649351
#       Period     Unemployed
# mean     3.0  261685.714286
#       Period     Unemployed
# mean     4.0  262792.857143
#       Period     Unemployed
# mean     5.0  258592.857143
#       Period     Unemployed
# mean     6.0  251378.571429
#       Period     Unemployed
# mean     7.0  265057.142857
#       Period     Unemployed
# mean     8.0  261142.857143
#       Period     Unemployed
# mean     9.0  261064.285714
#       Period     Unemployed
# mean    10.0  256978.571429
#       Period     Unemployed
# mean    11.0  257621.428571
#       Period     Unemployed
# mean    12.0  253392.857143
